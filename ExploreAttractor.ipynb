# %% [markdown]
# # Explore Attractor
# ## Cormac O'Connor

# %%
from attractor import Attractor
# %matplotlib inline

# %% [markdown]
# loads the Attractor class from the attractor file

# %%
a = Attractor()
a.evolve()
a.plot3d()

# %% [markdown]
# Plots the 3d plot of attractor with the initial values

# %%
a.plotx()
a.ploty()
a.plotz()

# %% [markdown]
# Plots x(t), y(t), z(t) with initial conditions

# %%
a.plotxy()
a.plotyz()
a.plotzx()

# %% [markdown]
# Plots x-y, y-z, z-x planar projections

# %% [markdown]
# Obviously none of the graphs are correct as they should be showing many curves and the 3D plot should show a bowtie-like graph. I believe it has to do with the shape and size of my self.solution and perhaps it is not populating correctly. I will be attempting to troubleshoot in the following days and hopefully update this to a working code.
